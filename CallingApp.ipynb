# %%
sales_call = {
    "Date": "2025-09-03",                      # String value
    "Salesperson": "Doug",                     # String value
    "Client Name": "Acme Corp",                # String value
    "Company Name": "Acme Corp",               # String value
    "Phone/Contact": "555-123-4567",           # String value

    "Relationship Type": "Prospect",           # Dropdown-style string
    "Communication Method": "Phone",           # Dropdown-style string

    "Revenue Size": "$6MM – $10MM",            # Dropdown-style string

    "Call Outcome": "Needs Follow-Up",         # Dropdown-style string

    "Products Discussed": [                    # List of strings
        "Loans",
        "Treasury Management"
    ],

    "Action Items": [                          # List of strings
        "Send Proposal",
        "Schedule Meeting"
    ],

    "Notes": "Client interested in expanding credit line. Wants proposal by Friday."  # Freeform string
}

# %%
sales_call
# Out:
# {'Date': '2025-09-03',
#  'Salesperson': 'Doug',
#  'Client Name': 'Acme Corp',
#  'Company Name': 'Acme Corp',
#  'Phone/Contact': '555-123-4567',
#  'Relationship Type': 'Prospect',
#  'Communication Method': 'Phone',
#  'Revenue Size': '$6MM – $10MM',
#  'Call Outcome': 'Needs Follow-Up',
#  'Products Discussed': ['Loans', 'Treasury Management'],
#  'Action Items': ['Send Proposal', 'Schedule Meeting'],
#  'Notes': 'Client interested in expanding credit line. Wants proposal by Friday.'}

# %%
import pprint
pprint.pprint(sales_call)
# Out:
# {'Action Items': ['Send Proposal', 'Schedule Meeting'],
#  'Call Outcome': 'Needs Follow-Up',
#  'Client Name': 'Acme Corp',
#  'Communication Method': 'Phone',
#  'Company Name': 'Acme Corp',
#  'Date': '2025-09-03',
#  'Notes': 'Client interested in expanding credit line. Wants proposal by '
#           'Friday.',
#  'Phone/Contact': '555-123-4567',
#  'Products Discussed': ['Loans', 'Treasury Management'],
#  'Relationship Type': 'Prospect',
#  'Revenue Size': '$6MM – $10MM',
#  'Salesperson': 'Doug'}

# %%
call_log = []
call_log.append(sales_call)

# %%
for call in call_log: 
    pprint.pprint(call)
# Out:
# {'Action Items': ['Send Proposal', 'Schedule Meeting'],
#  'Call Outcome': 'Needs Follow-Up',
#  'Client Name': 'Acme Corp',
#  'Communication Method': 'Phone',
#  'Company Name': 'Acme Corp',
#  'Date': '2025-09-03',
#  'Notes': 'Client interested in expanding credit line. Wants proposal by '
#           'Friday.',
#  'Phone/Contact': '555-123-4567',
#  'Products Discussed': ['Loans', 'Treasury Management'],
#  'Relationship Type': 'Prospect',
#  'Revenue Size': '$6MM – $10MM',
#  'Salesperson': 'Doug'}

# %%
import pandas as pd

# %%
df = pd.DataFrame(call_log)
df.head()
# Out:
#          Date Salesperson Client Name Company Name Phone/Contact  \
# 0  2025-09-03        Doug   Acme Corp    Acme Corp  555-123-4567
#
#   Relationship Type Communication Method  Revenue Size     Call Outcome  \
# 0          Prospect                Phone  $6MM – $10MM  Needs Follow-Up
#
#              Products Discussed                       Action Items  \
# 0  [Loans, Treasury Management]  [Send Proposal, Schedule Meeting]
#
#                                                Notes
# 0  Client interested in expanding credit line. Wa...

# %%
call_log = []

call_log.append(sales_call)

# Add another one
call_log.append({
    "Date": "2025-09-04",
    "Salesperson": "Doug",
    "Client Name": "Beta Inc",
    "Company Name": "Beta Inc",
    "Phone/Contact": "555-987-6543",
    "Relationship Type": "Referral",
    "Communication Method": "Virtual",
    "Revenue Size": "$11MM – $15MM",
    "Call Outcome": "Interested",
    "Products Discussed": ["SBA", "Corporate Card"],
    "Action Items": ["Email Summary", "Share Product Sheet"],
    "Notes": "Referred by COI. Interested in SBA options for expansion."
})

# %%
df = pd.DataFrame(call_log) 
df.head()
# Out:
#          Date Salesperson Client Name Company Name Phone/Contact  \
# 0  2025-09-03        Doug   Acme Corp    Acme Corp  555-123-4567
# 1  2025-09-04        Doug    Beta Inc     Beta Inc  555-987-6543
#
#   Relationship Type Communication Method   Revenue Size     Call Outcome  \
# 0          Prospect                Phone   $6MM – $10MM  Needs Follow-Up
# 1          Referral              Virtual  $11MM – $15MM       Interested
#
#              Products Discussed                          Action Items  \
# 0  [Loans, Treasury Management]     [Send Proposal, Schedule Meeting]
# 1         [SBA, Corporate Card]  [Email Summary, Share Product Sheet]
#
#                                                Notes
# 0  Client interested in expanding credit line. Wa...
# 1  Referred by COI. Interested in SBA options for...

# %%
sales_call = {
    "Date": "2025-09-03",
    "Salesperson": "Doug",
    "Client Name": "Acme Corp",
    "Company Name": "Acme Corp",
    "Contact Person": "Jane Smith",
    "Phone/Contact": "555-123-4567",
    "Relationship Type": "Existing Client",
    "Communication Method": "In-Person",
    "Revenue Size": "$5MM – $10MM",
    "Call Outcome": "Follow-up Needed",
    "Products Discussed": ["Line of Credit", "Treasury Services"],
    "Action Items": ["Send Proposal", "Schedule Demo"],
    "Notes": "Interested in expanding credit line. Wants demo next week."
}

# %%
call_log = [sales_call]
df = pd.DataFrame(call_log)
df.head()
# Out:
#          Date Salesperson Client Name Company Name Contact Person  \
# 0  2025-09-03        Doug   Acme Corp    Acme Corp     Jane Smith
#
#   Phone/Contact Relationship Type Communication Method  Revenue Size  \
# 0  555-123-4567   Existing Client            In-Person  $5MM – $10MM
#
#        Call Outcome                   Products Discussed  \
# 0  Follow-up Needed  [Line of Credit, Treasury Services]
#
#                      Action Items  \
# 0  [Send Proposal, Schedule Demo]
#
#                                                Notes
# 0  Interested in expanding credit line. Wants dem...

# %%
sales_call_2 = {
    "Date": "2025-09-03",
    "Salesperson": "Doug",
    "Client Name": "Summit Logistics",
    "Company Name": "Summit Logistics",
    "Contact Person": "Carlos Mendoza",
    "Phone/Contact": "913-555-7788",
    "Relationship Type": "New Prospect",
    "Communication Method": "Phone",
    "Revenue Size": "$25MM – $50MM",
    "Call Outcome": "Needs More Info",
    "Products Discussed": ["Fleet Financing", "Cash Management"],
    "Action Items": ["Send Case Study", "Schedule Onsite Visit"],
    "Notes": "Carlos is evaluating options for fleet expansion. Interested in competitive financing terms and bundled treasury solutions. Wants to loop in CFO next week."
}

# %%
df = pd.DataFrame(call_log) 
df.head()
# Out:
#          Date Salesperson Client Name Company Name Contact Person  \
# 0  2025-09-03        Doug   Acme Corp    Acme Corp     Jane Smith
#
#   Phone/Contact Relationship Type Communication Method  Revenue Size  \
# 0  555-123-4567   Existing Client            In-Person  $5MM – $10MM
#
#        Call Outcome                   Products Discussed  \
# 0  Follow-up Needed  [Line of Credit, Treasury Services]
#
#                      Action Items  \
# 0  [Send Proposal, Schedule Demo]
#
#                                                Notes
# 0  Interested in expanding credit line. Wants dem...

# %%
sales_call_3 = {
    "Date": "2025-09-03",
    "Salesperson": "Doug",
    "Client Name": "Prairie Tech",
    "Company Name": "Prairie Tech",
    "Contact Person": "Lena Cho",
    "Phone/Contact": "816-555-3344",
    "Relationship Type": "Existing Client",
    "Communication Method": "Virtual",
    "Revenue Size": "$10MM – $20MM",
    "Call Outcome": "Committed to Next Step",
    "Products Discussed": ["Merchant Services", "ACH Solutions"],
    "Action Items": ["Send Implementation Timeline", "Confirm Training Date"],
    "Notes": "Lena confirmed interest in upgrading ACH platform. Wants onboarding to begin next quarter. CFO already signed off."
}

# %%
call_log.append(sales_call_3)
df = pd.DataFrame(call_log)
df.head()
# Out:
#          Date Salesperson   Client Name  Company Name Contact Person  \
# 0  2025-09-03        Doug     Acme Corp     Acme Corp     Jane Smith
# 1  2025-09-03        Doug  Prairie Tech  Prairie Tech       Lena Cho
#
#   Phone/Contact Relationship Type Communication Method   Revenue Size  \
# 0  555-123-4567   Existing Client            In-Person   $5MM – $10MM
# 1  816-555-3344   Existing Client              Virtual  $10MM – $20MM
#
#              Call Outcome                   Products Discussed  \
# 0        Follow-up Needed  [Line of Credit, Treasury Services]
# 1  Committed to Next Step   [Merchant Services, ACH Solutions]
#
#                                         Action Items  \
# 0                     [Send Proposal, Schedule Demo]
# 1  [Send Implementation Timeline, Confirm Trainin...
#
#                                                Notes
# 0  Interested in expanding credit line. Wants dem...
# 1  Lena confirmed interest in upgrading ACH platf...
